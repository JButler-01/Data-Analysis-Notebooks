# %% [markdown]
# Assignment 1, Tutorial 2: 10 minutes to pandas
#
# Joshua Butler 100155237
#
# This excercise is to get a first hand experience using the tools in pandas

# %%
import numpy as np

import pandas as pd

# %%
x = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
x
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
d = pd.date_range("20130101", periods=6)

# %%
d
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dataframe = pd.DataFrame(np.random.randn(6, 4), index=d, columns=list("ABCD"))

# %%
dataframe
# Out:
#                    A         B         C         D
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949
# 2013-01-06 -0.892354 -1.525893 -1.204109  1.296007

# %%
dataframe2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["cat1", "cat2", "cat3", "cat1"]),
        "F": "foo",
    }
)

# %%
dataframe2
# Out:
#      A          B    C  D     E    F
# 0  1.0 2013-01-02  1.0  3  cat1  foo
# 1  1.0 2013-01-02  1.0  3  cat2  foo
# 2  1.0 2013-01-02  1.0  3  cat3  foo
# 3  1.0 2013-01-02  1.0  3  cat1  foo

# %%
dataframe2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
dataframe2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %% [markdown]
# Used this to look at column A

# %%
dataframe.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949

# %%
dataframe.tail()
# Out:
#                    A         B         C         D
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949
# 2013-01-06 -0.892354 -1.525893 -1.204109  1.296007

# %%
dataframe.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dataframe.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
dataframe.to_numpy()
# Out:
# array([[ 0.68818297, -0.26425853,  0.10109844, -1.35394021],
#        [ 2.08895415, -1.05456568,  0.39069939, -0.6072862 ],
#        [ 0.1847523 ,  1.87994693,  0.90149018, -1.13298823],
#        [-0.71349764,  0.79755515,  0.21430977, -0.89573177],
#        [ 0.27415241,  0.33969368, -0.96367002, -0.42894948],
#        [-0.89235446, -1.52589294, -1.20410868,  1.29600742]])

# %%
dataframe.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.271698  0.028746 -0.093363 -0.520481
# std    1.077875  1.248280  0.818256  0.951438
# min   -0.892354 -1.525893 -1.204109 -1.353940
# 25%   -0.488935 -0.856989 -0.697478 -1.073674
# 50%    0.229452  0.037718  0.157704 -0.751509
# 75%    0.584675  0.683090  0.346602 -0.473534
# max    2.088954  1.879947  0.901490  1.296007

# %%
dataframe.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.688183    2.088954    0.184752   -0.713498    0.274152   -0.892354
# B   -0.264259   -1.054566    1.879947    0.797555    0.339694   -1.525893
# C    0.101098    0.390699    0.901490    0.214310   -0.963670   -1.204109
# D   -1.353940   -0.607286   -1.132988   -0.895732   -0.428949    1.296007

# %%
dataframe.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.353940  0.101098 -0.264259  0.688183
# 2013-01-02 -0.607286  0.390699 -1.054566  2.088954
# 2013-01-03 -1.132988  0.901490  1.879947  0.184752
# 2013-01-04 -0.895732  0.214310  0.797555 -0.713498
# 2013-01-05 -0.428949 -0.963670  0.339694  0.274152
# 2013-01-06  1.296007 -1.204109 -1.525893 -0.892354

# %%
dataframe.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-06 -0.892354 -1.525893 -1.204109  1.296007
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988

# %%
dataframe["A"]
# Out:
# 2013-01-01    0.688183
# 2013-01-02    2.088954
# 2013-01-03    0.184752
# 2013-01-04   -0.713498
# 2013-01-05    0.274152
# 2013-01-06   -0.892354
# Freq: D, Name: A, dtype: float64

# %%
dataframe[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988

# %%
dataframe["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732

# %%
dataframe.loc[d[0]]
# Out:
# A    0.688183
# B   -0.264259
# C    0.101098
# D   -1.353940
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
dataframe.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.688183 -0.264259
# 2013-01-02  2.088954 -1.054566
# 2013-01-03  0.184752  1.879947
# 2013-01-04 -0.713498  0.797555
# 2013-01-05  0.274152  0.339694
# 2013-01-06 -0.892354 -1.525893

# %%
dataframe.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  2.088954 -1.054566
# 2013-01-03  0.184752  1.879947
# 2013-01-04 -0.713498  0.797555

# %%
dataframe.loc[d[0], "A"]
# Out:
# 0.6881829669666024

# %%
dataframe.at[d[0], "A"]
# Out:
# 0.6881829669666024

# %%
dataframe.iloc[3]
# Out:
# A   -0.713498
# B    0.797555
# C    0.214310
# D   -0.895732
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
dataframe.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.713498  0.797555
# 2013-01-05  0.274152  0.339694

# %%
dataframe.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  2.088954  0.390699
# 2013-01-03  0.184752  0.901490
# 2013-01-05  0.274152 -0.963670

# %%
dataframe.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988

# %%
dataframe.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.264259  0.101098
# 2013-01-02 -1.054566  0.390699
# 2013-01-03  1.879947  0.901490
# 2013-01-04  0.797555  0.214310
# 2013-01-05  0.339694 -0.963670
# 2013-01-06 -1.525893 -1.204109

# %%
dataframe.iloc[1, 1]
# Out:
# -1.0545656825564267

# %%
dataframe.iat[1, 1]
# Out:
# -1.0545656825564267

# %%
dataframe[dataframe["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949

# %%
dataframe[dataframe > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.688183       NaN  0.101098       NaN
# 2013-01-02  2.088954       NaN  0.390699       NaN
# 2013-01-03  0.184752  1.879947  0.901490       NaN
# 2013-01-04       NaN  0.797555  0.214310       NaN
# 2013-01-05  0.274152  0.339694       NaN       NaN
# 2013-01-06       NaN       NaN       NaN  1.296007

# %%
dataframe2 = dataframe.copy()

# %%
dataframe2["E"] = ["one", "two", "three", "four", "four", "five"]

# %%
dataframe2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.688183 -0.264259  0.101098 -1.353940    one
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286    two
# 2013-01-03  0.184752  1.879947  0.901490 -1.132988  three
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732   four
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949   four
# 2013-01-06 -0.892354 -1.525893 -1.204109  1.296007   five

# %%
dataframe2[dataframe2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-02  2.088954 -1.054566  0.390699 -0.607286   two
# 2013-01-04 -0.713498  0.797555  0.214310 -0.895732  four
# 2013-01-05  0.274152  0.339694 -0.963670 -0.428949  four

# %%
x2 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
x2
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
dataframe["F"] = x2

# %%
dataframe.at[d[0], "A"] = 0

# %%
dataframe.iat[0, 1] = 0

# %%
dataframe.loc[:, "D"] = np.array([5] * len(dataframe))
# Out:
# <ipython-input-55-86f11117d153>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dataframe.loc[:, "D"] = np.array([5] * len(dataframe))

# %%
dataframe2 = dataframe.copy()

# %%
dataframe2[dataframe2 > 0] = -dataframe2

# %%
dataframe2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.101098 -5  NaN
# 2013-01-02 -2.088954 -1.054566 -0.390699 -5 -1.0
# 2013-01-03 -0.184752 -1.879947 -0.901490 -5 -2.0
# 2013-01-04 -0.713498 -0.797555 -0.214310 -5 -3.0
# 2013-01-05 -0.274152 -0.339694 -0.963670 -5 -4.0
# 2013-01-06 -0.892354 -1.525893 -1.204109 -5 -5.0

# %%
dataframe1 = dataframe.reindex(index=d[0:4], columns=list(dataframe.columns) + ["E"])

# %%
dataframe1.loc[d[0] : d[1], "E"] = 1

# %%
dataframe1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.101098  5  NaN  1.0
# 2013-01-02  2.088954 -1.054566  0.390699  5  1.0  1.0
# 2013-01-03  0.184752  1.879947  0.901490  5  2.0  NaN
# 2013-01-04 -0.713498  0.797555  0.214310  5  3.0  NaN

# %%
dataframe1.dropna(how="any")
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  2.088954 -1.054566  0.390699  5  1.0  1.0

# %%
dataframe1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.101098  5  5.0  1.0
# 2013-01-02  2.088954 -1.054566  0.390699  5  1.0  1.0
# 2013-01-03  0.184752  1.879947  0.901490  5  2.0  5.0
# 2013-01-04 -0.713498  0.797555  0.214310  5  3.0  5.0

# %%
pd.isna(dataframe1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
dataframe.mean()
# Out:
# A    0.157001
# B    0.072790
# C   -0.093363
# D    5.000000
# F    3.000000
# dtype: float64

# %%
dataframe.mean(axis=1)
# Out:
# 2013-01-01    1.275275
# 2013-01-02    1.485018
# 2013-01-03    1.993238
# 2013-01-04    1.659673
# 2013-01-05    1.730035
# 2013-01-06    1.275529
# Freq: D, dtype: float64

# %%
x = pd.Series([1, 3, 5, np.nan, 6, 8], index=d).shift(2)

# %%
x
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
dataframe.sub(x, axis="index")
# Out:
#                    A         B        C    D    F
# 2013-01-01       NaN       NaN      NaN  NaN  NaN
# 2013-01-02       NaN       NaN      NaN  NaN  NaN
# 2013-01-03 -0.815248  0.879947 -0.09851  4.0  1.0
# 2013-01-04 -3.713498 -2.202445 -2.78569  2.0  0.0
# 2013-01-05 -4.725848 -4.660306 -5.96367  0.0 -1.0
# 2013-01-06       NaN       NaN      NaN  NaN  NaN

# %%
dataframe.agg(lambda k: np.mean(k) * 5.6)
# Out:
# A     0.879206
# B     0.407621
# C    -0.522836
# D    28.000000
# F    16.800000
# dtype: float64

# %%
dataframe.transform(lambda k: k * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000   10.231162  506.0    NaN
# 2013-01-02  211.402160 -106.722047   39.538779  506.0  101.2
# 2013-01-03   18.696933  190.250630   91.230807  506.0  202.4
# 2013-01-04  -72.205961   80.712582   21.688149  506.0  303.6
# 2013-01-05   27.744223   34.377001  -97.523406  506.0  404.8
# 2013-01-06  -90.306272 -154.420365 -121.855798  506.0  506.0

# %%
x = pd.Series(np.random.randint(0, 7, size=10))

# %%
x
# Out:
# 0    2
# 1    2
# 2    6
# 3    4
# 4    3
# 5    3
# 6    4
# 7    5
# 8    4
# 9    4
# dtype: int64

# %%
x.value_counts()
# Out:
# 4    4
# 2    2
# 3    2
# 6    1
# 5    1
# dtype: int64

# %%
x = pd.Series(["L", "M", "N", "Dede", "Defg", np.nan, "CHEESE", "Wolf", "LIZARD"])

# %%
x.str.lower()
# Out:
# 0         l
# 1         m
# 2         n
# 3      dede
# 4      defg
# 5       NaN
# 6    cheese
# 7      wolf
# 8    lizard
# dtype: object

# %%
dataframe = pd.DataFrame(np.random.randn(10, 4))

# %%
dataframe
# Out:
#           0         1         2         3
# 0 -1.259960  1.606789 -1.326969 -0.419686
# 1 -0.965471  0.615148 -0.657770 -0.388990
# 2  0.841009 -1.251635  0.366137  0.396208
# 3  1.477082 -0.873984 -0.119396  0.217605
# 4 -1.034318 -0.234874  1.688982 -1.073101
# 5 -0.777288 -1.062906  0.517601 -0.536936
# 6 -0.584978  1.041882 -0.772869 -0.331762
# 7  0.376145  1.343554  0.196824  0.099924
# 8  1.165841  0.673054 -0.266036  1.064170
# 9  0.442979  2.705436  0.340128 -0.916043

# %%
parts = [dataframe[:3], dataframe[3:7], dataframe[7:]]

# %%
pd.concat(parts)
# Out:
#           0         1         2         3
# 0 -1.259960  1.606789 -1.326969 -0.419686
# 1 -0.965471  0.615148 -0.657770 -0.388990
# 2  0.841009 -1.251635  0.366137  0.396208
# 3  1.477082 -0.873984 -0.119396  0.217605
# 4 -1.034318 -0.234874  1.688982 -1.073101
# 5 -0.777288 -1.062906  0.517601 -0.536936
# 6 -0.584978  1.041882 -0.772869 -0.331762
# 7  0.376145  1.343554  0.196824  0.099924
# 8  1.165841  0.673054 -0.266036  1.064170
# 9  0.442979  2.705436  0.340128 -0.916043
